# %% [markdown]
# # Visualize Boosting Trees

# %%
import sys
# !{sys.executable} -m pip install graphviz
import xgboost as xgb
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
# %matplotlib inline
import os

# %%
booster = xgb.Booster()
xg_model_weighted = booster.load_model(fname='./model_weighted')

# %%
pickle_in = open("xg_model_weighted.pickle","rb")
xg_model_weighted = pickle.load(pickle_in)

# %%
os.environ["PATH"] += os.pathsep + 'C:/Program Files (x86)/Graphviz2.38/bin/'
# C:\Program Files (x86)\Graphviz2.38\bin

# %%
xgb.plot_tree(xg_model_weighted,num_trees=15)
plt.rcParams['figure.figsize'] = [50, 10]
plt.show()

# %%
xgb.plot_tree(xg_model_weighted, num_trees=15)
fig = plt.gcf()
fig.set_size_inches(150, 100)
# fig
# fig.savefig('tree.png')
